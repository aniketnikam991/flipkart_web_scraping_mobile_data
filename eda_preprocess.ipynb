# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("flipkart_mobile_phones_data.csv")

# %%
df
# Out:
#      Unnamed: 0                                    Product Name  \
# 0             0              realme P4x 5G (Lake Green, 128 GB)
# 1             1                  Coolpad CP12 Neo (Gold, 64 GB)
# 2             2    MOTOROLA g06 power (Pantone tapestry, 64 GB)
# 3             3  MOTOROLA g06 power (Pantone Laurel Oak, 64 GB)
# 4             4     MOTOROLA g06 power (Pantone Tendril, 64 GB)
# ..          ...                                             ...
# 979         979           realme 15 5G (Flowing Silver, 256 GB)
# 980         980                realme 15 5G (Silk Pink, 256 GB)
# 981         981             realme 15 5G (Velvet Green, 256 GB)
# 982         982             realme 15 5G (Velvet Green, 128 GB)
# 983         983                realme 15 5G (Silk Pink, 128 GB)
#
#       Sale & Actual Price             Raview & Rattings    Offer  \
# 0    ₹16,499₹17,9998% off   7,161 Ratings & 549 Reviews   8% off
# 1     ₹7,299₹9,99927% off                           NaN  27% off
# 2     ₹7,999₹9,99920% off   6,394 Ratings & 382 Reviews  20% off
# 3     ₹7,999₹9,99920% off   6,394 Ratings & 382 Reviews  20% off
# 4     ₹7,999₹9,99920% off   6,394 Ratings & 382 Reviews  20% off
# ..                    ...                           ...      ...
# 979  ₹30,999₹31,9993% off  10,672 Ratings & 863 Reviews   3% off
# 980  ₹30,999₹31,9993% off  10,672 Ratings & 863 Reviews   3% off
# 981  ₹30,999₹31,9993% off  10,672 Ratings & 863 Reviews   3% off
# 982  ₹28,999₹29,9993% off  10,672 Ratings & 863 Reviews   3% off
# 983  ₹28,999₹29,9993% off  10,672 Ratings & 863 Reviews   3% off
#
#                                   Camera  \
# 0          50MP + 2MP | 8MP Front Camera
# 1    13MP Rear Camera | 5MP Front Camera
# 2    50MP Rear Camera | 8MP Front Camera
# 3    50MP Rear Camera | 8MP Front Camera
# 4    50MP Rear Camera | 8MP Front Camera
# ..                                   ...
# 979       50MP + 8MP | 50MP Front Camera
# 980       50MP + 8MP | 50MP Front Camera
# 981       50MP + 8MP | 50MP Front Camera
# 982       50MP + 8MP | 50MP Front Camera
# 983       50MP + 8MP | 50MP Front Camera
#
#                                             Memory           Battery  \
# 0                            6 GB RAM | 128 GB ROM  7000 mAh Battery
# 1    8 GB RAM | 64 GB ROM | Expandable Upto 512 GB  5000 mAh Battery
# 2      4 GB RAM | 64 GB ROM | Expandable Upto 1 TB  7000 mAh Battery
# 3      4 GB RAM | 64 GB ROM | Expandable Upto 1 TB  7000 mAh Battery
# 4      4 GB RAM | 64 GB ROM | Expandable Upto 1 TB  7000 mAh Battery
# ..                                             ...               ...
# 979                          8 GB RAM | 256 GB ROM  7000 mAh Battery
# 980                          8 GB RAM | 256 GB ROM  7000 mAh Battery
# 981                          8 GB RAM | 256 GB ROM  7000 mAh Battery
# 982                          8 GB RAM | 128 GB ROM  7000 mAh Battery
# 983                          8 GB RAM | 128 GB ROM  7000 mAh Battery
#
#                                    Display  Ratting Number
# 0    17.07 cm (6.72 inch) Full HD+ Display             4.4
# 1             16.66 cm (6.56 inch) Display             NaN
# 2         17.48 cm (6.88 inch) HD+ Display             4.3
# 3         17.48 cm (6.88 inch) HD+ Display             4.3
# 4         17.48 cm (6.88 inch) HD+ Display             4.3
# ..                                     ...             ...
# 979            17.27 cm (6.8 inch) Display             4.4
# 980            17.27 cm (6.8 inch) Display             4.4
# 981            17.27 cm (6.8 inch) Display             4.4
# 982            17.27 cm (6.8 inch) Display             4.4
# 983            17.27 cm (6.8 inch) Display             4.4
#
# [984 rows x 10 columns]

# %%
df = df.drop("Unnamed: 0", axis = 1)

# %%
df["Sale & Actual Price"][0].split(df["Offer"][0])[0].split("₹")[1].replace(",", "")
# Out:
# '16499'

# %%
df.iloc[219]
# Out:
# Product Name           MOTOROLA Edge 60 Pro (Pantone Shadow, 256 GB)
# Sale & Actual Price                            ₹29,999₹36,99918% off
# Raview & Rattings                     46,783 Ratings & 3,440 Reviews
# Offer                                                        18% off
# Camera                        50MP + 50MP + 10MP | 50MP Front Camera
# Memory                                         8 GB RAM | 256 GB ROM
# Battery                                             6000 mAh Battery
# Display                                  17.02 cm (6.7 inch) Display
# Ratting Number                                                   4.3
# Name: 219, dtype: object

# %%
sale_price = []
actual_price = []

for i in range(df.shape[0]):
    try:
        a = df["Sale & Actual Price"][i].split(df["Offer"][i])[0].split("₹")[1]
        sale_price.append(int(a.replace(",", "")))

        try:
            b = df["Sale & Actual Price"][i].split(df["Offer"][i])[0].split("₹")[2]
        except IndexError:
            b = a

        actual_price.append(int(b.replace(",", "")))
    except IndexError:
        sale_price.append(df["Sale & Actual Price"][i])
        actual_price.append(df["Sale & Actual Price"][i])

# %%
df["Sale Price"] = sale_price
df["Actual Price"] = actual_price

# %%
df = df.drop("Sale & Actual Price", axis = 1)

# %%
splitted_cols = df['Raview & Rattings'].str.split("&", expand=True)

# %%
df
# Out:
#                                        Product Name  \
# 0                realme P4x 5G (Lake Green, 128 GB)
# 1                    Coolpad CP12 Neo (Gold, 64 GB)
# 2      MOTOROLA g06 power (Pantone tapestry, 64 GB)
# 3    MOTOROLA g06 power (Pantone Laurel Oak, 64 GB)
# 4       MOTOROLA g06 power (Pantone Tendril, 64 GB)
# ..                                              ...
# 979           realme 15 5G (Flowing Silver, 256 GB)
# 980                realme 15 5G (Silk Pink, 256 GB)
# 981             realme 15 5G (Velvet Green, 256 GB)
# 982             realme 15 5G (Velvet Green, 128 GB)
# 983                realme 15 5G (Silk Pink, 128 GB)
#
#                 Raview & Rattings    Offer  \
# 0     7,161 Ratings & 549 Reviews   8% off
# 1                             NaN  27% off
# 2     6,394 Ratings & 382 Reviews  20% off
# 3     6,394 Ratings & 382 Reviews  20% off
# 4     6,394 Ratings & 382 Reviews  20% off
# ..                            ...      ...
# 979  10,672 Ratings & 863 Reviews   3% off
# 980  10,672 Ratings & 863 Reviews   3% off
# 981  10,672 Ratings & 863 Reviews   3% off
# 982  10,672 Ratings & 863 Reviews   3% off
# 983  10,672 Ratings & 863 Reviews   3% off
#
#                                   Camera  \
# 0          50MP + 2MP | 8MP Front Camera
# 1    13MP Rear Camera | 5MP Front Camera
# 2    50MP Rear Camera | 8MP Front Camera
# 3    50MP Rear Camera | 8MP Front Camera
# 4    50MP Rear Camera | 8MP Front Camera
# ..                                   ...
# 979       50MP + 8MP | 50MP Front Camera
# 980       50MP + 8MP | 50MP Front Camera
# 981       50MP + 8MP | 50MP Front Camera
# 982       50MP + 8MP | 50MP Front Camera
# 983       50MP + 8MP | 50MP Front Camera
#
#                                             Memory           Battery  \
# 0                            6 GB RAM | 128 GB ROM  7000 mAh Battery
# 1    8 GB RAM | 64 GB ROM | Expandable Upto 512 GB  5000 mAh Battery
# 2      4 GB RAM | 64 GB ROM | Expandable Upto 1 TB  7000 mAh Battery
# 3      4 GB RAM | 64 GB ROM | Expandable Upto 1 TB  7000 mAh Battery
# 4      4 GB RAM | 64 GB ROM | Expandable Upto 1 TB  7000 mAh Battery
# ..                                             ...               ...
# 979                          8 GB RAM | 256 GB ROM  7000 mAh Battery
# 980                          8 GB RAM | 256 GB ROM  7000 mAh Battery
# 981                          8 GB RAM | 256 GB ROM  7000 mAh Battery
# 982                          8 GB RAM | 128 GB ROM  7000 mAh Battery
# 983                          8 GB RAM | 128 GB ROM  7000 mAh Battery
#
#                                    Display  Ratting Number  Sale Price  \
# 0    17.07 cm (6.72 inch) Full HD+ Display             4.4       16499
# 1             16.66 cm (6.56 inch) Display             NaN        7299
# 2         17.48 cm (6.88 inch) HD+ Display             4.3        7999
# 3         17.48 cm (6.88 inch) HD+ Display             4.3        7999
# 4         17.48 cm (6.88 inch) HD+ Display             4.3        7999
# ..                                     ...             ...         ...
# 979            17.27 cm (6.8 inch) Display             4.4       30999
# 980            17.27 cm (6.8 inch) Display             4.4       30999
# 981            17.27 cm (6.8 inch) Display             4.4       30999
# 982            17.27 cm (6.8 inch) Display             4.4       28999
# 983            17.27 cm (6.8 inch) Display             4.4       28999
#
#      Actual Price
# 0           17999
# 1            9999
# 2            9999
# 3            9999
# 4            9999
# ..            ...
# 979         31999
# 980         31999
# 981         31999
# 982         29999
# 983         29999
#
# [984 rows x 10 columns]

# %%
splitted_cols.value_counts()
# Out:
# 0                1
# 7,161 Ratings     549 Reviews      20
# 6,922 Ratings     406 Reviews      10
# 43,589 Ratings    2,715 Reviews     9
# 44,538 Ratings    2,650 Reviews     9
# 16,259 Ratings    869 Reviews       8
#                                    ..
# 4,284 Ratings     306 Reviews       1
# 34 Ratings        1 Reviews         1
# 2,300 Ratings     163 Reviews       1
# 294 Ratings       11 Reviews        1
# 3,899 Ratings     194 Reviews       1
# Name: count, Length: 351, dtype: int64

# %%
splitted_cols [0] = splitted_cols[0].fillna('7,161 Ratings')

# %%
splitted_cols[1]=splitted_cols[1].fillna(' 549  Reviews')

# %%
df["No of Reviews"] = splitted_cols[0].str.replace(",", "").str.extract(r"(\d+)").astype(int)
df["No of Rattings"] = splitted_cols[1].str.replace(",", "").str.extract(r"(\d+)").astype(int)

# %%
final_df = df.drop("Raview & Rattings", axis = 1)

# %%
final_df.to_csv("processed_flipkart_mobile_phones_data.csv")

# %%
final_df.shape
# Out:
# (984, 11)

# %%
final_df
# Out:
#                                        Product Name    Offer  \
# 0                realme P4x 5G (Lake Green, 128 GB)   8% off
# 1                    Coolpad CP12 Neo (Gold, 64 GB)  27% off
# 2      MOTOROLA g06 power (Pantone tapestry, 64 GB)  20% off
# 3    MOTOROLA g06 power (Pantone Laurel Oak, 64 GB)  20% off
# 4       MOTOROLA g06 power (Pantone Tendril, 64 GB)  20% off
# ..                                              ...      ...
# 979           realme 15 5G (Flowing Silver, 256 GB)   3% off
# 980                realme 15 5G (Silk Pink, 256 GB)   3% off
# 981             realme 15 5G (Velvet Green, 256 GB)   3% off
# 982             realme 15 5G (Velvet Green, 128 GB)   3% off
# 983                realme 15 5G (Silk Pink, 128 GB)   3% off
#
#                                   Camera  \
# 0          50MP + 2MP | 8MP Front Camera
# 1    13MP Rear Camera | 5MP Front Camera
# 2    50MP Rear Camera | 8MP Front Camera
# 3    50MP Rear Camera | 8MP Front Camera
# 4    50MP Rear Camera | 8MP Front Camera
# ..                                   ...
# 979       50MP + 8MP | 50MP Front Camera
# 980       50MP + 8MP | 50MP Front Camera
# 981       50MP + 8MP | 50MP Front Camera
# 982       50MP + 8MP | 50MP Front Camera
# 983       50MP + 8MP | 50MP Front Camera
#
#                                             Memory           Battery  \
# 0                            6 GB RAM | 128 GB ROM  7000 mAh Battery
# 1    8 GB RAM | 64 GB ROM | Expandable Upto 512 GB  5000 mAh Battery
# 2      4 GB RAM | 64 GB ROM | Expandable Upto 1 TB  7000 mAh Battery
# 3      4 GB RAM | 64 GB ROM | Expandable Upto 1 TB  7000 mAh Battery
# 4      4 GB RAM | 64 GB ROM | Expandable Upto 1 TB  7000 mAh Battery
# ..                                             ...               ...
# 979                          8 GB RAM | 256 GB ROM  7000 mAh Battery
# 980                          8 GB RAM | 256 GB ROM  7000 mAh Battery
# 981                          8 GB RAM | 256 GB ROM  7000 mAh Battery
# 982                          8 GB RAM | 128 GB ROM  7000 mAh Battery
# 983                          8 GB RAM | 128 GB ROM  7000 mAh Battery
#
#                                    Display  Ratting Number  Sale Price  \
# 0    17.07 cm (6.72 inch) Full HD+ Display             4.4       16499
# 1             16.66 cm (6.56 inch) Display             NaN        7299
# 2         17.48 cm (6.88 inch) HD+ Display             4.3        7999
# 3         17.48 cm (6.88 inch) HD+ Display             4.3        7999
# 4         17.48 cm (6.88 inch) HD+ Display             4.3        7999
# ..                                     ...             ...         ...
# 979            17.27 cm (6.8 inch) Display             4.4       30999
# 980            17.27 cm (6.8 inch) Display             4.4       30999
# 981            17.27 cm (6.8 inch) Display             4.4       30999
# 982            17.27 cm (6.8 inch) Display             4.4       28999
# 983            17.27 cm (6.8 inch) Display             4.4       28999
#
#      Actual Price  No of Reviews  No of Rattings
# 0           17999           7161             549
# 1            9999           7161             549
# 2            9999           6394             382
# 3            9999           6394             382
# 4            9999           6394             382
# ..            ...            ...             ...
# 979         31999          10672             863
# 980         31999          10672             863
# 981         31999          10672             863
# 982         29999          10672             863
# 983         29999          10672             863
#
# [984 rows x 11 columns]
